# %% [markdown]
# # Print Function

# %%
print("Hello World")
print(2)
print(2.443)
print(True)
print(1,2,3,4.33)

# %%
print("Hello",123,True,4.55,sep="....")

# %%
print("Hello")
print("World")

# %%
print("Hello",end='---')
print("World")

# %% [markdown]
# # Data Types and Data Structures

# %%
# maximum value of int is pow(10,308)
# long long is embedded in integer data type
a=10
print(a)
max=1e308

print(max)

# %%
# max decimal value is = 1.7 * pow(10,308)
print(5.66)
max=1.7e308
print(max)

# %%
print(True)
print(False)

# %%
print("String")
print("Ayush Budhlakoti")

# %%
# complex numbers
print(5+6j)

# %%
# List is like Array
print([1,2,3,4,5])

# %%
# Tuple = immutable
print((1,2,3,4,5))

# %%
# Sets = only unique values in sorted order
print({1,2,2,3,3,3,4,5})

# %%
# Dictionary= {Key-Value} Pairs
print({"Name":"Ayush","Age":21,"Gender":"Male"})

# %% [markdown]
# # Type() Function

# %%
# Gives the type of data type or data structure
print(type(5))
print(type(9.544))
print(type(True))
print(type("Hello"))
print(type(5+8j))

# %% [markdown]
# # Variables

# %%
name="Ayush Budhlakoti"
print(name)

# %%
# Dynamic Typing = Language automatically detects the data type
# Python is a dynamically typed language
a=12
print(a)

# Static Typing = Need to declare the type of variable (like c,c++, java)
# int n=22;
# print(n)

# %%
# Dynamic Binding = DataType of the variable can be changed
a=12
print(a)
a="Ayush"
print(a)

# %%
a,b,c=1,2,3
print(a,b,c)

# %%
a=b=c=34
print(a,b,c)

# %% [markdown]
# # Keywords and Identifiers

# %%
# keywords are reserved words having a special meaning. 35 KeyWords in python
# identifiers are the names given to the variables and data structures

# %% [markdown]
# # Taking User Input

# %%
input("Enter number: ")

# %%
# By Default input()  takes string as input, because string is a universal DataType
# it can store anything
a=int(input("Enter num1: "))
b=int(input("Enter num2: "))
sum=a+b
print(sum)
print(type(sum))
print(type(a),type(b))

# %% [markdown]
# # Type Conversion

# %%
# Implicit typecasting = automatic conversion

# Explicit typeCasting
a=int(2.33)
print(type(a))
s=str(1234)
print(type(s))

# %% [markdown]
# # Literals (Raw Values)

# %%
a=123      # Decimal
b=0b1010   # Binary
c=0o123    # Octal
d=0x12c   # HexaDecimal
print(a,b,c,d,sep="----")
print(type(a),type(b),type(c),type(d),sep="----")

x=10.2
y=1.5e3
z=1.5e-2
print(x,y,z,sep="----")

com=12+13j
print(com.real,com.imag,sep="----")

# %% [markdown]
# # Strings

# %%
s='Ayush'
str="Ayush"
multiline="""Ayush is a 
good boy"""
unicode=u"\U0001f600"  # any character (emoji, any language, any symbol)
rawString=r"this is a \n raw string"  # ignores escape characters like /n and /t

print(s)
print(str)
print(multiline)
print(unicode)
print(rawString)

# %%
# boolean true is 1
# boolean false is 0

a= True+5
b= False-10
print(a)
print(b)

# %%
# none is used when we declare a variable but not initialized
a=None
print(a)

# %% [markdown]
# # Arithematic Operators

# %%
a=10
b=8
print(a+b,a-b,a*b,a/b,a//b,a%b,a**b)

# %% [markdown]
# # Relational Operators

# %%
a=10
b=8

print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a!=b)

# %% [markdown]
# # Logical Operators

# %%
print(1 and 0) 
print(1 and 1)

print(0 or 0)
print(1 or 0)
print(0 or 1)

print(not 0)
print(not 1)

# %% [markdown]
# # Bitwise operators

# %%
# They operates on binary values
print(2&3)
print(2|3)
print(~2)
print(2^3)
print(4>>1)
print(4<<1)

# %% [markdown]
# # Assignment Operator

# %%
# incremant and decrement is not present in python
a=12
a+=12
a-=12
a%=3

# %% [markdown]
# # Membership Operator

# %%
# used to check that a value exists inside a collection.

print('D' in "Delhi")
print("X" in "Delhi")

print('D' not in "Delhi")
print("X" not in "Delhi")

print(1 in [1,2,3,4,5])
print(12 in [1,2,3,4,5])

# %% [markdown]
# # Conditional Statements

# %%
mail=input("Enter your msil sddtrdd: ")
password=input("Enter Password: ")

if mail=="ayush@gmail.com" and password=="1234":
    print("successfully logged in")
elif mail=="ayush@gmail.com" and password!="1234":
    print("wrong password")
else:
    print("Wrong Credentials")

# %% [markdown]
# # Modules

# %%
import math
print(math.factorial(4))
print(math.sqrt(16))

# %%
import keyword
print(keyword.kwlist) # gives list of all keywords in python

# %%
import random
print(random.randint(1,100))

# %%
import datetime as dt
print(dt.datetime.now())

# %%
help()

# %%
n=5
i=1
print("Printing table of ",n)
while i<=10:
    print(n*i)
    i+=1

# %%
i=1
while i<3:
    print(i)
    i+=1
else:
    print("Loop Completed")

# The else block executes only if the loop finishes normally (without hitting break statement).

# %%
import random
n=random.randint(1,100)
print("Chal ab ek number guess krr")
win=False
guess=int(input("Enter guess: "))
chance=5
while chance>0:
    if(guess==n):
        print("Jeet Gya ")
        win=True
        break
    elif(guess<n):
        print("Thoda bada number guess krr ")
    else:
        print("Thoda chota number guess krr ")
    chance-=1
    guess=int(input("le ab guess daal: "))
else:
    if(win==False):
        print("Haar gya")

# %%
for i in range(1,11):
    print(i)

# %%
for i in range(1,11,2):
    print(i)

# %%
for i in range(10,0,-1):
    print(i)

# %%
for i in [10,20,30,40,50]:
    print(i)

# %%
for i in (1,2,2,23,4):
    print(i)

# %%
for i in {10,20,20,20,30,40,40}:
    print(i)

# %%
p=int(input("Enter current Population: "))
for i in range(1,11):
    p+=(p/100)*10
    print(p)
