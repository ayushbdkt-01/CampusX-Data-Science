# %%
def convert(n):
    ans=""
    while(n>0):
        if(n%2==0): ans= str(0)+ans
        else: ans=str(1)+ans
        n=n//2

    return ans


n=int(input("Enter number in decimal: "))
print(convert(n))
# Out:
# 1010

# %%
s="Data Science Mentorship Program"

l=[]

l.append(s[0])
for i in range(0, len(s)):
    if s[i]==' ': l.append(s[i+1])

print(l)
# Out:
# ['D', 'S', 'M', 'P']

# %%
s="Ankit Bisht Madarchod Hai"
revStr=s[::-1]
ansStr=""

prevIndex=0

for i in range(0,len(revStr)):
    if(revStr[i]==' '):
        ansStr+=revStr[i:prevIndex-1:-1]
        prevIndex=i

ansStr+=revStr[len(s)-1:prevIndex-1:-1]
print(ansStr)
# Out:
#  Madarchod  Bisht Ankit

# %%
s="Ankit Bisht Madarchod Hai"

l=[]
prevIndex=0

for i in range(0,len(s)):
    if(s[i]==' '): l.append(s[prevIndex:i])
    prevIndex=i+1

l.append(s[prevIndex:len(s)])

print(l)

reversed(l)
print(l)
# Out:
# ['', '', '', '']
# ['', '', '', '']
